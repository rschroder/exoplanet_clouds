# %%
from jupyterthemes import jtplot
jtplot.style()
# %matplotlib inline
from clausius import *
from molecular_species import *
from planet_atmospheres import *
from clausius_plot import *

plot_pressure_curves(venus, [SO4H2_liquid_1_v, SO4H2_liquid_2_v])
plot_pressure_curves(earth, [H20_liquid_1_e, H20_solid_1_e])
plot_pressure_curves(mars, [CO2_solid_1_m, H20_solid_1_m])
plot_pressure_curves(hd209458b, [MGSIO3_solid_1_HD209458b, FE_solid_1_HD209458b])
plot_pressure_curves(saturn, [NH3_solid_1_saturn])
# Out:
# clausius.py:35: RuntimeWarning: divide by zero encountered in divide
#   alpha_term*np.log(T)  + T*beta_term))
# clausius.py:35: RuntimeWarning: divide by zero encountered in log
#   alpha_term*np.log(T)  + T*beta_term))
# clausius.py:35: RuntimeWarning: invalid value encountered in add
#   alpha_term*np.log(T)  + T*beta_term))

# %%
np.log(7.19407)
# Out:
# 1.9732570755569241
