# %%
#from jupyterthemes import jtplot
#jtplot.style()
# %matplotlib inline
#import seaborn
from clausius import *
from molecular_species import *
from planet_atmospheres import *
from clausius_plot import *

#plot_pressure_curves(jupiter, [NH3_solid_1_jupiter, NH4SH_solid_1_jupiter, \
#                               H20_solid_1_jupiter, H20_liquid_1_jupiter])
#plot_pressure_curves(saturn, [NH3_solid_1_saturn, NH4SH_solid_1_saturn, H20_solid_1_saturn])
#plot_pressure_curves(titan, [CH4_solid_1_titan, C2H6_solid_1_titan])
#plot_pressure_curves(uranus, [CH4_solid_1_uranus, SH2_solid_1_uranus, NH3_solid_1_uranus,\
#                             NH4SH_solid_1_uranus, H20_solid_1_uranus])

#plot_pressure_curves(venus, [SO4H2_liquid_1_venus, SO4H2_liquid_2_venus])
#plot_pressure_curves(earth, [H20_liquid_1_earth, H20_solid_1_earth])
#plot_pressure_curves(neptune, [CH4_solid_1_neptune, SH2_solid_1_neptune, NH3_solid_1_neptune,\
#                             NH4SH_solid_1_neptune, H20_solid_1_neptune])

## the curve for wasp43b uses a random mole fraction for Fe
#plot_pressure_curves(WASP43b, [H20_liquid_1_WASP43b])
plot_pressure_curves_cba(hd209458b, 7.100,  -21723,  0.4536)
plot_pressure_curves_cba(WASP43b, 7.100,  -21723,  0.4536) # try a condensible species on neptune instead 
plot_pressure_curves_cba(HD189733b, 7.100,  -21723,  0.4536)              # just to test svp curves
# Out:
# [-833.60111811] km
# [ 1910.] K
# [ 3.43480251] bar
#
# [-769.12593913] km
# [ 1854.] K
# [ 3.12213915] bar
#
# [-706.28523707] km
# [ 1801.] K
# [ 2.84481157] bar
#
# [-645.28270915] km
# [ 1751.] K
# [ 2.59918069] bar
# [] km
# [] K
# [] bar
#
# [] km
# [] K
# [] bar
#
# [] km
# [] K
# [] bar
#
# [-2236.82211253] km
# [ 2170.] K
# [ 47376742.84907962] bar
# [-401.94204234] km
# [ 1926.] K
# [ 6.62789974] bar
#
# [-379.77779285] km
# [ 1869.] K
# [ 5.97149235] bar
#
# [-358.14749307] km
# [ 1815.] K
# [ 5.39362771] bar
#
# [-337.11962859] km
# [ 1764.] K
# [ 4.88551263] bar

# %%
from astro import *
# g_e(earth_masses, earth_radii):
surface_gravity = g_e(21.36, 4.327)
print surface_gravity
# Out:
# 11.1784744863

# %%
Cp = 18.0
adiabatic_gradient = surface_gravity/Cp
print adiabatic_gradient
# Out:
# 0.62102636035

# %%
from astro import *
# g_j(jupiter_masses, jupiter_radii):
surface_gravity_wasp = g_j(2.052, 1.036)
print surface_gravity_wasp

surface_gravity_hd = g_j(1.142, 1.138)
print surface_gravity_hd
# Out:
# 47.3885470225
# 21.8573309029

# %%
Cp = 14.0
adiabatic_gradient = 21.2/Cp
print adiabatic_gradient
ag = 3.7/Cp
print ag
# Out:
# 1.51428571429
# 0.264285714286

# %%
np.log(4.5)
# Out:
# 1.5040773967762742
